# %%
import numpy as np
from pylab import *

np.random.seed(2)

page_S = np.random.normal(5.0, 3.0, 100)
purchase_A = np.random.normal(50.0, 30.0, 100) / page_S


scatter(page_S, purchase_A)

# %%
trainX = page_S[:80]
testX = page_S[80:]

trainY = purchase_A[:80]
testY = purchase_A[80:]

# %%
scatter(trainX,trainY)

# %%
scatter(testX, testY)

# %%
train_x = np.array(trainX)
train_y = np.array(trainY)

p4 = np.poly1d(np.polyfit(x, y, 8))

# %%
import matplotlib.pyplot as plt

LP = np.linspace(0, 15, 500)
axes = plt.axes()
axes.set_xlim([0,15])
axes.set_ylim([-50, 150])
plt.scatter(x, y)
plt.plot(LP, p4(LP), c='r')

# %%
test_x = np.array(testX)
test_y = np.array(testY)

axes = plt.axes()
axes.set_xlim([0,15])
axes.set_ylim([-50, 150])
plt.scatter(test_x, test_y)
plt.plot(LP, p4(LP), c='r')
plt.show()

# %%
from sklearn.metrics import r2_score

r2 = r2_score(test_y, p4(test_x))

print(r2)
# Out:
# 0.4554475661771903

# %%
from sklearn.metrics import r2_score

r2 = r2_score(np.array(trainY), p4(np.array(trainX)))

print(r2)
# Out:
# 0.43672060290198944
